# %%
# ============================================================
# 🏛️ Supreme Court Judgments Downloader (2020–2025)
# Downloads .txt + .json files from AWS Open Data (India)
# Saves year-wise into: D:\LPA_MTech_Project\My_Datasets\SC_2020-2025
# ============================================================

# %%
import os
import boto3
import botocore
import json
import pandas as pd
from tqdm import tqdm

# %%
# ---------- CONFIG ----------
LOCAL_SAVE_DIR = r"D:\LPA_MTech_Project\My_Datasets\SC_1990-2009"
START_YEAR = 1990
END_YEAR = 2009
BUCKET_NAME = "indian-supreme-court-judgments"
# ----------------------------

# %%
os.makedirs(LOCAL_SAVE_DIR, exist_ok=True)

# %%
# Anonymous S3 client (public dataset)
# s3 = boto3.client("s3", config=boto3.session.Config(signature_version="unsigned"))

s3 = boto3.client(
    "s3",
    config=botocore.client.Config(signature_version=botocore.UNSIGNED)
)

# %%
def list_zip_files_in_year(year):
    """List zip files (English + metadata) for each year."""
    prefixes = [
        f"data/zip/year={year}/",
        f"metadata/zip/year={year}/"
    ]
    for prefix in prefixes:
        paginator = s3.get_paginator("list_objects_v2")
        for page in paginator.paginate(Bucket=BUCKET_NAME, Prefix=prefix):
            for obj in page.get("Contents", []):
                key = obj["Key"]
                if key.endswith(".zip"):
                    yield key

# %%
def download_zip_file(key, local_path):
    """Download one zip file if not already downloaded."""
    if os.path.exists(local_path):
        return
    os.makedirs(os.path.dirname(local_path), exist_ok=True)
    try:
        s3.download_file(BUCKET_NAME, key, local_path)
    except Exception as e:
        print(f"❌ Error downloading {key}: {e}")

# %%
# ---------- DOWNLOAD SECTION ----------
for year in range(START_YEAR, END_YEAR + 1):
    print(f"\n📦 Downloading ZIP files for {year} ...")
    year_dir = os.path.join(LOCAL_SAVE_DIR, str(year))
    os.makedirs(year_dir, exist_ok=True)

    keys = list(list_zip_files_in_year(year))
    print(f"Found {len(keys)} zip files for {year}")

    for key in tqdm(keys, desc=f"Year {year}", unit="zip"):
        filename = key.split("/")[-1]
        local_path = os.path.join(year_dir, filename)
        download_zip_file(key, local_path)

print("\n✅ ZIP downloads complete for all years.")
# Out:
# 📦 Downloading ZIP files for 1990 ...
# Found 3 zip files for 1990
# Year 1990: 100%|██████████| 3/3 [00:43<00:00, 14.64s/zip]
# 📦 Downloading ZIP files for 1991 ...
# Found 3 zip files for 1991
# Year 1991: 100%|██████████| 3/3 [00:45<00:00, 15.04s/zip]
# 📦 Downloading ZIP files for 1992 ...
# Found 3 zip files for 1992
# Year 1992: 100%|██████████| 3/3 [00:44<00:00, 14.90s/zip]
# 📦 Downloading ZIP files for 1993 ...
# Found 3 zip files for 1993
# Year 1993: 100%|██████████| 3/3 [00:51<00:00, 17.13s/zip]
# 📦 Downloading ZIP files for 1994 ...
# Found 3 zip files for 1994
# Year 1994: 100%|██████████| 3/3 [01:00<00:00, 20.22s/zip]
# 📦 Downloading ZIP files for 1995 ...
# Found 3 zip files for 1995
# Year 1995: 100%|██████████| 3/3 [02:04<00:00, 41.37s/zip]
# 📦 Downloading ZIP files for 1996 ...
# Found 3 zip files for 1996
# Year 1996: 100%|██████████| 3/3 [04:00<00:00, 80.22s/zip]
# 📦 Downloading ZIP files for 1997 ...
# Found 3 zip files for 1997
# Year 1997: 100%|██████████| 3/3 [02:10<00:00, 43.54s/zip]
# 📦 Downloading ZIP files for 1998 ...
# Found 3 zip files for 1998
# Year 1998: 100%|██████████| 3/3 [01:08<00:00, 22.91s/zip]
# 📦 Downloading ZIP files for 1999 ...
# Found 3 zip files for 1999
# Year 1999: 100%|██████████| 3/3 [01:13<00:00, 24.35s/zip]
# 📦 Downloading ZIP files for 2000 ...
# Found 3 zip files for 2000
# Year 2000: 100%|██████████| 3/3 [00:58<00:00, 19.65s/zip]
# 📦 Downloading ZIP files for 2001 ...
# Found 3 zip files for 2001
# Year 2001: 100%|██████████| 3/3 [01:05<00:00, 21.70s/zip]
# 📦 Downloading ZIP files for 2002 ...
# Found 3 zip files for 2002
# Year 2002: 100%|██████████| 3/3 [01:13<00:00, 24.57s/zip]
# 📦 Downloading ZIP files for 2003 ...
# Found 3 zip files for 2003
# Year 2003: 100%|██████████| 3/3 [01:20<00:00, 26.92s/zip]
# 📦 Downloading ZIP files for 2004 ...
# Found 3 zip files for 2004
# Year 2004: 100%|██████████| 3/3 [01:17<00:00, 25.80s/zip]
# 📦 Downloading ZIP files for 2005 ...
# Found 3 zip files for 2005
# Year 2005: 100%|██████████| 3/3 [01:05<00:00, 21.69s/zip]
# 📦 Downloading ZIP files for 2006 ...
# Found 3 zip files for 2006
# Year 2006: 100%|██████████| 3/3 [01:33<00:00, 31.16s/zip]
# 📦 Downloading ZIP files for 2007 ...
# Found 3 zip files for 2007
# Year 2007: 100%|██████████| 3/3 [01:50<00:00, 36.97s/zip]
# 📦 Downloading ZIP files for 2008 ...
# Found 3 zip files for 2008
# Year 2008: 100%|██████████| 3/3 [02:34<00:00, 51.55s/zip]
# 📦 Downloading ZIP files for 2009 ...
# Found 3 zip files for 2009
# Year 2009: 100%|██████████| 3/3 [01:07<00:00, 22.64s/zip]
# ✅ ZIP downloads complete for all years.

# %%
# ---------- OPTIONAL: Extract ZIPs ----------
import zipfile

for year in range(START_YEAR, END_YEAR + 1):
    year_dir = os.path.join(LOCAL_SAVE_DIR, str(year))
    print(f"\n📂 Extracting ZIPs in {year_dir}")
    for file in os.listdir(year_dir):
        if file.endswith(".zip"):
            zip_path = os.path.join(year_dir, file)
            extract_dir = os.path.join(year_dir, file.replace(".zip", ""))
            if not os.path.exists(extract_dir):
                os.makedirs(extract_dir, exist_ok=True)
                with zipfile.ZipFile(zip_path, 'r') as zf:
                    zf.extractall(extract_dir)
print("\n✅ All ZIPs extracted successfully!")
# Out:
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1990
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1991
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1992
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1993
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1994
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1995
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1996
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1997
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1998
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1999
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2000
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2001
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2002
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2003
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2004
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2005
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2006
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2007
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2008
#
# 📂 Extracting ZIPs in D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2009
#
# ✅ All ZIPs extracted successfully!

# %%
# ============================================================
# 📊 METADATA CSV BUILDER
# ============================================================

# %%
metadata_records = []

# %%
for year in range(START_YEAR, END_YEAR + 1):
    year_dir = os.path.join(LOCAL_SAVE_DIR, str(year))
    print(f"\n🧩 Extracting metadata from {year_dir}")
    
    # Look inside each extracted metadata folder
    for root, _, files in os.walk(year_dir):
        for file in files:
            if file.endswith(".json"):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, "r", encoding="utf-8") as f:
                        data = json.load(f)

                    record = {
                        "year": year,
                        "file_name": file,
                        "case_name": data.get("case_name") or data.get("title") or "",
                        "date": data.get("date") or data.get("judgment_date") or "",
                        "bench": data.get("bench") or "",
                        "judges": ", ".join(data.get("judges", [])) if isinstance(data.get("judges"), list) else data.get("judges", ""),
                        "citations": ", ".join(data.get("citations", [])) if isinstance(data.get("citations"), list) else data.get("citations", ""),
                        "verdict_summary": data.get("verdict_summary", ""),
                        "url": data.get("url") or data.get("link") or "",
                    }
                    metadata_records.append(record)
                except Exception as e:
                    print(f"⚠️ Error reading {file}: {e}")
# Out:
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1990
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1991
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1992
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1993
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1994
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1995
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1996
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1997
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1998
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\1999
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2000
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2001
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2002
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2003
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2004
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2005
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2006
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2007
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2008
#
# 🧩 Extracting metadata from D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\2009

# %%
# Create DataFrame
metadata_df = pd.DataFrame(metadata_records)
csv_path = os.path.join(LOCAL_SAVE_DIR, "cases_metadata_1990_2009.csv")
metadata_df.to_csv(csv_path, index=False, encoding="utf-8-sig")

# %%
print(f"\n✅ Metadata CSV created successfully: {csv_path}")
print(f"Total cases processed: {len(metadata_df)}")
metadata_df.head()
# Out:
# ✅ Metadata CSV created successfully: D:\LPA_MTech_Project\My_Datasets\SC_1990-2009\cases_metadata_1990_2009.csv
# Total cases processed: 15216
#    year              file_name case_name date bench judges citations  \
# 0  1990  1990_1_1027_1030.json
# 1  1990  1990_1_1031_1040.json
# 2  1990    1990_1_115_133.json
# 3  1990    1990_1_134_143.json
# 4  1990      1990_1_13_19.json
#
#   verdict_summary url
# 0
# 1
# 2
# 3
# 4
