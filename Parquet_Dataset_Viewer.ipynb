# %%
import pandas as pd

# %%
# Load your enriched dataset
df = pd.read_parquet("D:\LPA_MTech_Project\Enriched_Datasets")

# Quick shape info
print(df.shape)
# Out:
# (4367, 34)

# %%
# List all column names
print(df.columns.tolist())
# Out:
# ['case_id', 'year', 'decision_date', 'case_no', 'bench_info', 'bench_size', 'judges', 'petitioner', 'respondent', 'disposal_nature', 'verdict_label', 'raw_html', 'text', 'decade', 'num_words_text', 'num_lines', 'act_names', 'sections', 'ipc_mentions', 'num_unique_acts', 'num_ipc_refs', 'has_ipc', 'sentiment_score', 'petitioner_mentions', 'respondent_mentions', 'pet_vs_resp_ratio', 'keywords', 'case_type', 'citations', 'num_citations', 'constitution_articles', 'has_constitution_article', 'ipc_mentions_extra', 'total_ipc_mentions']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4367 entries, 0 to 4366
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   case_id                   4367 non-null   object
#  1   year                      4367 non-null   int64
#  2   decision_date             4367 non-null   object
#  3   case_no                   4367 non-null   object
#  4   bench_info                4367 non-null   object
#  5   bench_size                4367 non-null   int64
#  6   judges                    4367 non-null   object
#  7   petitioner                4367 non-null   object
#  8   respondent                4367 non-null   object
#  9   disposal_nature           4223 non-null   object
#  10  verdict_label             4061 non-null   float64
#  11  raw_html                  4367 non-null   object
#  12  text                      4367 non-null   object
# ...

# %%
pd.set_option('display.max_columns', None)  # so all columns are visible
print(df.head(3))
# Out:
#              case_id  year decision_date            case_no  \
# 0  2020_10_1043_1074  2020    01-09-2020     CIVIL APPEAL N
# 1  2020_10_1075_1131  2020    02-09-2020  CRIMINAL APPEAL N
# 2  2020_10_1132_1150  2020    07-09-2020     CIVIL APPEAL N
#
#                bench_info  bench_size             judges  \
# 0  2 Judges Flip view PDF           1  [A.M. KHANWILKAR]
# 1  2 Judges Flip view PDF           1     [R.F. NARIMAN]
# 2  2 Judges Flip view PDF           1    [ASHOK BHUSHAN]
#
#                                 petitioner                      respondent  \
# 0      M/S. L. R. BROTHERS INDO FLORA LTD.  COMMISSIONER OF CENTRAL EXCISE
# 1    M/S BANDEKAR BROTHERS PVT. LTD. & ANR  PRASAD VASSUDEV KENI, ETC. ETC
# 2  THE NEW INDIA ASSURANCE COMPANY LIMITED         SMT. SOMWATI AND OTHERS
#
#        disposal_nature  verdict_label  \
# 0            Dismissed            0.0
# 1         Disposed off            1.0
# 2  Case Partly allowed            1.0
#
# ...

# %%
df.head()
# Out:
#              case_id  year decision_date                case_no  \
# 0  2020_10_1043_1074  2020    01-09-2020         CIVIL APPEAL N
# 1  2020_10_1075_1131  2020    02-09-2020      CRIMINAL APPEAL N
# 2  2020_10_1132_1150  2020    07-09-2020         CIVIL APPEAL N
# 3    2020_10_135_237  2020    11-08-2020  DIARYNO AND DIARYYR N
# 4       2020_10_1_26  2020    29-04-2020         CIVIL APPEAL N
#
#                bench_info  bench_size              judges  \
# 0  2 Judges Flip view PDF           1   [A.M. KHANWILKAR]
# 1  2 Judges Flip view PDF           1      [R.F. NARIMAN]
# 2  2 Judges Flip view PDF           1     [ASHOK BHUSHAN]
# 3  3 Judges Flip view PDF           1       [ARUN MISHRA]
# 4  2 Judges Flip view PDF           1  [UDAY UMESH LALIT]
#
#                                 petitioner                      respondent  \
# 0      M/S. L. R. BROTHERS INDO FLORA LTD.  COMMISSIONER OF CENTRAL EXCISE
# 1    M/S BANDEKAR BROTHERS PVT. LTD. & ANR  PRASAD VASSUDEV KENI, ETC. ETC
# ...

# %%
# df.describe(include='all').T

# %%
df.isna().sum().sort_values(ascending=False).head(15)
# Out:
# verdict_label      306
# disposal_nature    144
# year                 0
# case_id              0
# bench_info           0
# decision_date        0
# bench_size           0
# judges               0
# petitioner           0
# case_no              0
# respondent           0
# raw_html             0
# text                 0
# decade               0
# num_words_text       0
# dtype: int64

# %%
# Check verdict class balance
df['verdict_label'].value_counts(normalize=True)

# Distribution of case types
df['case_type'].value_counts(normalize=True)

# IPC density
print("Cases with IPC:", df['has_ipc'].sum(), "/", len(df))
# Out:
# Cases with IPC: 4351 / 4367
